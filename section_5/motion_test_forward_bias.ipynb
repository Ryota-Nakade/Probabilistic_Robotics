# %%
import sys
sys.path.append('../scripts/')
from robot import *

# %%
world = World(40.0, 0.1)

initial_pose = np.array([0,0,0]).T
robots = []

for i in range(100):
    r = Robot(initial_pose, sensor=None, agent=Agent(0.1, 0.0))
    world.append(r)
    robots.append(r)
    
world.draw()
# Out:
# <img src="data:image/png;base64,..." width="718.8889079329414">

# %%
import pandas as pd
poses = pd.DataFrame([ [math.sqrt(r.pose[0]**2 + r.pose[1]**2), r.pose[2]] for r in robots],
                    columns=['r', 'theta'])
poses.transpose()
# Out:
#              0         1         2         3         4         5         6   \
# r      3.891867  4.275334  4.132935  4.112170  3.817747  4.333787  4.539034
# theta  0.024886 -0.399451 -0.600032 -0.076176 -0.361898  0.020985 -0.087065
#
#              7         8         9   ...        90        91        92  \
# r      4.016779  4.235699  3.475582  ...  3.935312  4.065572  4.859925
# theta  0.399263 -0.220062 -0.215264  ...  0.081531  0.066226 -0.003938
#
#              93        94        95        96        97        98        99
# r      3.833439  3.723273  4.197362  3.355129  3.759196  3.813479  4.212851
# theta -0.165785  0.315433  0.220803 -0.067222  0.052497  0.379650  0.573449
#
# [2 rows x 100 columns]

# %%
print(poses["r"].var())
print(poses["r"].mean())
math.sqrt(poses["r"].var()/poses["r"].mean())
# Out:
# 0.16008274964346136
# 4.0431938749804415
# 0.19898025556155488

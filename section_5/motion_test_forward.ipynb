# %%
import sys
sys.path.append('../scripts/')
from robot import *

# %%
import copy

world = World(40.0, 0.1)

initial_pose = np.array([0,0,0]).T
robots = []
r = Robot(initial_pose, sensor=None, agent=Agent(0.1, 0.0))

for i in range(100):
    copy_r = copy.copy(r)
    copy_r.distance_until_noise = copy_r.noise_pdf.rvs()
    world.append(copy_r)
    robots.append(copy_r)
    
world.draw()
# Out:
# <img src="data:image/png;base64,..." width="718.8889079329414">

# %%
import pandas as pd
poses = pd.DataFrame([ [math.sqrt(r.pose[0]**2 + r.pose[1]**2), r.pose[2]] for r in robots],
                    columns=['r', 'theta'])
poses.transpose()
# Out:
#              0         1         2         3         4         5         6   \
# r      2.447382  2.444963  2.444315  2.442944  2.446035  2.448417  2.446913
# theta -0.066246  0.058771 -0.269658  0.185649 -0.169225  0.117407  0.003223
#
#              7         8         9   ...        90        91        92  \
# r      2.444418  2.438529  2.435064  ...  2.429806  2.440877  2.447034
# theta -0.135761 -0.166968 -0.285163  ... -0.427555 -0.176195  0.105433
#
#              93        94        95        96        97        98        99
# r      2.446464  2.440201  2.428664  2.449445  2.430777  2.447382  2.446210
# theta  0.164649  0.040523  0.351407  0.049773  0.405540 -0.000746 -0.048258
#
# [2 rows x 100 columns]

# %%
print(poses["theta"].var())
print(poses["r"].mean())
math.sqrt(poses["theta"].var()/poses["r"].mean())
# Out:
# 0.03694415887149763
# 2.4431318808173064
# 0.1229700744945139
